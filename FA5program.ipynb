# %% [markdown]
# <a href="https://colab.research.google.com/github/sigeonsigeoncodecode/FA5programactivity/blob/main/FA5program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calculate_total(price, quantity):
    return price * quantity
price = float(input("Enter the price of one item: "))

quantity = int(input("Enter the number of items purchased: "))

total = calculate_total(price, quantity)

print("The total price is:", total)
# Out:
# Enter the price of one item: 12
# Enter the number of items purchased: 4
# The total price is: 48.0
